# %%
# %matplotlib inline
import numpy as np
import matplotlib.pylab as plt
import pyabf

# %%
abf = pyabf.ABF("neuron firing data/raw/PC040_0006.abf")
print(abf.headerText) # displays command waveform (DAC)
# Out:
# ### ABF Class Methods ###
# abf.getAllXs()
# abf.getAllYs()
# abf.launchInClampFit()
# abf.saveABF1()
# abf.setSweep()
# abf.sweepD()
#
# ### ABF Class Variables ###
# abfDateTime = 2022-01-11 21:07:02.560000
# abfDateTimeString = 2022-01-11T21:07:02.560
# abfFileComment =
# abfFilePath = /Users/hstrey/Documents/programming/Modeling-SDEs/neuron firing data/raw/PC040_0006.abf
# abfFolderPath = /Users/hstrey/Documents/programming/Modeling-SDEs/neuron firing data/raw
# abfID = PC040_0006
# abfVersion = {'major': 2, 'minor': 9, 'bugfix': 0, 'build': 0}
# abfVersionString = 2.9.0.0
# adcNames = ['Im_primar']
# adcUnits = ['mV']
# channelCount = 1
# channelList = [0]
# creator = Clampex 11.0.3.3
# creatorVersion = {'major': 11, 'minor': 0, 'bugfix': 3, 'build': 3}
# creatorVersionString = 11.0.3.3
# dacNames = ['Cmd 0']
# dacUnits = ['pA']
# data = [[-68.9392 -69.9463 -70.0684 ... -69.1528 -69.1223 -69.0918]]
# dataByteStart = 19456
# dataLengthMin = 8.533333333333333
# ...

# %%
x = abf.getAllXs()
y = abf.getAllYs()
plt.plot(x, y)
#plt.xlim((0,2))
plt.ylim((-75,50))
# Out:
# (-75.0, 50.0)

# %%
abf = pyabf.ABF("neuron firing data/raw/PC040_0006.abf")
abf.setSweep(20)
plt.figure(figsize=(8, 5))
plt.plot(abf.sweepX, abf.sweepY)
#plt.plot(abf.sweepX, abf.sweepC)
abf2 = pyabf.ABF("neuron firing data/raw/PC044_0003.abf")
abf2.setSweep(8)
#plt.figure(figsize=(8, 5))
plt.plot(abf2.sweepX, abf2.sweepY)
#plt.plot(abf.sweepX, abf.sweepC)

# %%
abf = pyabf.ABF("neuron firing data/raw/PC044_0003.abf")
abf.setSweep(8)
plt.figure(figsize=(8, 5))
plt.plot(abf.sweepX, abf.sweepY)
#plt.plot(abf.sweepX, abf.sweepC)
